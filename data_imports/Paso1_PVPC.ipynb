# %% [markdown]
# # Paso 1.-  Datos del precio de venta cliente
#
# Como primer paso vamos a obtener los datos de precio venta cleinte de la web https://www.esios.ree.es/. Esta web nos proporciona por medio de una Api multitud de datos que podemos utilizar. Para la correcta extracción vamos a utilizar algunas librerías.
#
# ## Librerías:
#
# Utilizaremos la Librería de https://pypi.org/project/esiosdata/ que permite acceder de manera fácil a la API. Instalación:
# - Se debe instalar por medio de "conda install pip"
# - https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-pkgs.html#installing-non-conda-packages
# - pip3 install esiosdata (dentro del env) (pip simple si no funciona)
# - echo "874b2aeaf4071f8db7085e0ca6aa88ede7e2992360fc0d6ad7af625b30b9e3bf" > ~/.token_api_esios
#
#
#
# ## Obtención de datos PVPC
# Vamos a obtener los datos de PVPC y de sus tarifas relacionadas.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
from esiosdata import PVPC
from esiosdata.prettyprinting import *
from datetime import datetime

pvpc_handler = PVPC()
# Out:
# WARNING:root:--> NO SE LEE DB_HDF (Exception: ValueError:The file '/Users/davidcerezallanda/.esiosdata/esiospvpc.h5' is already opened, but not in read-only mode (as requested).)
# WARNING:root:--> Se procede a realizar la captura de TODOS los datos existentes:
# --> NO SE LEE DB_HDF (Exception: ValueError:The file '/Users/davidcerezallanda/.esiosdata/esiospvpc.h5' is already opened, but not in read-only mode (as requested).)
# --> Se procede a realizar la captura de TODOS los datos existentes:
#
# PROCESADO DE DATOS WEB DE 1958 DÍAS
# Procesado de tareas en paralelo [1->50, %=2.6]: 1.75 seg [0.0350 seg/tarea]
# Procesado de tareas en paralelo [51->100, %=5.1]: 1.63 seg [0.0327 seg/tarea]
# Procesado de tareas en paralelo [101->150, %=7.7]: 1.62 seg [0.0324 seg/tarea]
# Procesado de tareas en paralelo [151->200, %=10.2]: 1.61 seg [0.0322 seg/tarea]
# Fichero irregular nº horas != 24: --> 26-10-2014 -> 25 medidas
# Procesado de tareas en paralelo [201->250, %=12.8]: 1.68 seg [0.0336 seg/tarea]
# Procesado de tareas en paralelo [251->300, %=15.3]: 1.63 seg [0.0326 seg/tarea]
# Procesado de tareas en paralelo [301->350, %=17.9]: 1.61 seg [0.0322 seg/tarea]
# Fichero irregular nº horas != 24: --> 29-03-2015 -> 23 medidas
# Procesado de tareas en paralelo [351->400, %=20.4]: 1.68 seg [0.0335 seg/tarea]
# Procesado de tareas en paralelo [401->450, %=23.0]: 2.73 seg [0.0546 seg/tarea]
# Procesado de tareas en paralelo [451->500, %=25.5]: 1.64 seg [0.0327 seg/tarea]
# Procesado de tareas en paralelo [501->550, %=28.1]: 1.63 seg [0.0325 seg/tarea]
# Fichero irregular nº horas != 24: --> 25-10-2015 -> 25 medidas
# Procesado de tareas en paralelo [551->600, %=30.6]: 1.66 seg [0.0332 seg/tarea]
# Procesado de tareas en paralelo [601->650, %=33.2]: 1.62 seg [0.0324 seg/tarea]
# Procesado de tareas en paralelo [651->700, %=35.8]: 1.61 seg [0.0323 seg/tarea]
# Fichero irregular nº horas != 24: --> 27-03-2016 -> 23 medidas
# Procesado de tareas en paralelo [701->750, %=38.3]: 1.62 seg [0.0324 seg/tarea]
# Procesado de tareas en paralelo [751->800, %=40.9]: 1.63 seg [0.0327 seg/tarea]
# Procesado de tareas en paralelo [801->850, %=43.4]: 1.85 seg [0.0370 seg/tarea]
# Procesado de tareas en paralelo [851->900, %=46.0]: 1.97 seg [0.0395 seg/tarea]
# Fichero irregular nº horas != 24: --> 30-10-2016 -> 25 medidas
# Procesado de tareas en paralelo [901->950, %=48.5]: 1.80 seg [0.0361 seg/tarea]
# Procesado de tareas en paralelo [951->1000, %=51.1]: 1.84 seg [0.0367 seg/tarea]
# Procesado de tareas en paralelo [1001->1050, %=53.6]: 1.56 seg [0.0312 seg/tarea]
# Fichero irregular nº horas != 24: --> 26-03-2017 -> 23 medidas
# Procesado de tareas en paralelo [1051->1100, %=56.2]: 1.69 seg [0.0339 seg/tarea]
# Procesado de tareas en paralelo [1101->1150, %=58.7]: 1.59 seg [0.0318 seg/tarea]
# Procesado de tareas en paralelo [1151->1200, %=61.3]: 2.11 seg [0.0422 seg/tarea]
# Procesado de tareas en paralelo [1201->1250, %=63.8]: 1.83 seg [0.0367 seg/tarea]
# Procesado de tareas en paralelo [1251->1300, %=66.4]: 1.86 seg [0.0372 seg/tarea]
# Fichero irregular nº horas != 24: --> 29-10-2017 -> 25 medidas
# Procesado de tareas en paralelo [1301->1350, %=68.9]: 2.73 seg [0.0547 seg/tarea]
# Procesado de tareas en paralelo [1351->1400, %=71.5]: 1.79 seg [0.0358 seg/tarea]
# Procesado de tareas en paralelo [1401->1450, %=74.1]: 2.66 seg [0.0532 seg/tarea]
# Fichero irregular nº horas != 24: --> 25-03-2018 -> 23 medidas
# Procesado de tareas en paralelo [1451->1500, %=76.6]: 1.68 seg [0.0337 seg/tarea]
# Procesado de tareas en paralelo [1501->1550, %=79.2]: 1.84 seg [0.0368 seg/tarea]
# Procesado de tareas en paralelo [1551->1600, %=81.7]: 1.70 seg [0.0339 seg/tarea]
# Procesado de tareas en paralelo [1601->1650, %=84.3]: 1.74 seg [0.0348 seg/tarea]
# Fichero irregular nº horas != 24: --> 28-10-2018 -> 25 medidas
# Procesado de tareas en paralelo [1651->1700, %=86.8]: 1.73 seg [0.0346 seg/tarea]
# Procesado de tareas en paralelo [1701->1750, %=89.4]: 2.17 seg [0.0434 seg/tarea]
# Procesado de tareas en paralelo [1751->1800, %=91.9]: 1.80 seg [0.0360 seg/tarea]
# Fichero irregular nº horas != 24: --> 31-03-2019 -> 23 medidas
# Procesado de tareas en paralelo [1801->1850, %=94.5]: 1.61 seg [0.0321 seg/tarea]
# Procesado de tareas en paralelo [1851->1900, %=97.0]: 1.77 seg [0.0354 seg/tarea]
# Procesado de tareas en paralelo [1901->1950, %=99.6]: 2.04 seg [0.0408 seg/tarea]
# Procesado de tareas en paralelo [1951->1958, %=100.0]: 0.36 seg [0.0444 seg/tarea]
# Tiempo de proceso de tareas en paralelo TOTAL (1958 tareas): 71.11 seg [0.0363 seg/tarea]
#
# MERGE DATAFRAMES DE DATOS WEB DIARIOS (392 GRUPOS)
# Procesado de tareas en paralelo [1->392, %=100.0]: 38.11 seg [0.0972 seg/tarea]
#
# 1958 días importados [Proceso Total 129.10 seg, 0.0659 seg/día]
# 	Nº rows:	46992 samples
# 	Última:	10-08-2019 23:00

# %%
import pandas as pd
import numpy as np

df_pvpc = pvpc_handler.data['data']
df_pvpc.tail()
# Out:
#                            CCVGEN  CCVNOC  CCVVHC    COFGEN    COFNOC    COFVHC  FOMGEN  FOMNOC  FOMVHC  FOSGEN  FOSNOC  FOSVHC  ...  PMHGEN  PMHNOC  PMHVHC  SAHGEN  SAHNOC  SAHVHC  TEUGEN  TEUNOC  TEUVHC     VHC  \
# fecha                                                                                                                            ...
# 2019-08-10 19:00:00+02:00    1.85    1.87    1.87  0.000125  0.000076  0.000062    0.03    0.03    0.03    0.13    0.13    0.13  ...   52.46   52.86   52.86    1.22    1.23    1.23   44.03   62.01   62.01  124.58
# 2019-08-10 20:00:00+02:00    1.93    1.95    1.95  0.000128  0.000081  0.000064    0.03    0.03    0.03    0.13    0.13    0.13  ...   57.17   57.61   57.61    1.15    1.16    1.16   44.03   62.01   62.01  129.37
# 2019-08-10 21:00:00+02:00    1.97    1.98    1.98  0.000139  0.000128  0.000146    0.03    0.03    0.03    0.13    0.13    0.13  ...   59.53   60.04   60.04    1.07    1.08    1.08   44.03   62.01   62.01  131.77
# 2019-08-10 22:00:00+02:00    1.96    1.98    1.98  0.000136  0.000150  0.000199    0.03    0.03    0.03    0.13    0.13    0.13  ...   58.74   59.24   59.24    1.17    1.18    1.18   44.03   62.01   62.01  131.07
# 2019-08-10 23:00:00+02:00    1.93    1.80    1.88  0.000122  0.000147  0.000184    0.03    0.03    0.03    0.13    0.13    0.13  ...   56.15   54.11   56.38    1.39    1.33    1.39   44.03    2.22    2.88   64.87
#
#                                                date  date_timestamp
# fecha
# 2019-08-10 19:00:00+02:00 2019-08-10 19:00:00+02:00    1.565456e+09
# 2019-08-10 20:00:00+02:00 2019-08-10 20:00:00+02:00    1.565460e+09
# 2019-08-10 21:00:00+02:00 2019-08-10 21:00:00+02:00    1.565464e+09
# 2019-08-10 22:00:00+02:00 2019-08-10 22:00:00+02:00    1.565467e+09
# 2019-08-10 23:00:00+02:00 2019-08-10 23:00:00+02:00    1.565471e+09
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Limpiar cierta información no usable
#
# Ponemos como límite inferior el día 1 de Octubre del 2015, será el que utilizaremos en los demás parámetros ya que es el primer día del que se dispone del preci PVPC.

# %%
df_pvpc = df_pvpc[df_pvpc['date'] >= '2015-10-01']

#Other prices cleanup
df_pvpc = df_pvpc[pvpc_handler.tarifas]
df_pvpc.rename({'GEN': 'PVPC_DEF', 'NOC': 'PVPC_2_PED_NOC', 'VHC': 'PVPC_ELEC_NOC'}, axis=1, inplace=True)

#timestamp adding
df_pvpc['date'] = pd.to_datetime(df_pvpc.index)
df_pvpc['date_timestamp'] = df_pvpc['date'].apply(lambda x:  datetime.timestamp(x))
print(df_pvpc.shape)
# Out:
# (33840, 5)

# %%
df_pvpc.head()
# Out:
#                            PVPC_DEF  PVPC_2_PED_NOC  PVPC_ELEC_NOC                      date  date_timestamp
# fecha
# 2015-10-01 00:00:00+02:00    117.77           69.49          71.88 2015-10-01 00:00:00+02:00    1.443650e+09
# 2015-10-01 01:00:00+02:00    117.09           68.21          65.57 2015-10-01 01:00:00+02:00    1.443654e+09
# 2015-10-01 02:00:00+02:00    114.59           65.34          62.53 2015-10-01 02:00:00+02:00    1.443658e+09
# 2015-10-01 03:00:00+02:00    116.60           66.53          63.40 2015-10-01 03:00:00+02:00    1.443661e+09
# 2015-10-01 04:00:00+02:00    122.07           71.03          67.37 2015-10-01 04:00:00+02:00    1.443665e+09

# %%
df_pvpc.to_csv('data_precios.csv')
