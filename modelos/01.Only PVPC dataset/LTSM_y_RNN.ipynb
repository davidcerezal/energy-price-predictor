# %% [markdown]
# #Modelos Neuronales y secuenciales (Full Dataset)

# %% [markdown]
# ##Carga de librerías y preparación de datos

# %% [markdown]
# Antes de preparar todo, elegimos el modelo a utilizar y alguna variable adicional:

# %%
skipDenseAct = True
skipLSTMAct = False
skipLSTM24Seg = False
skipLSTM24Agr = False

# %% [markdown]
# Para elegir qué celdas se ejecután y cuáles no:

# %% [markdown]
# Ahora pasamos a la carga de librerías y preparación de datos:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras.backend as K
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation, SimpleRNN, LSTM, Dropout, BatchNormalization, GRU
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.optimizers import SGD
from keras.regularizers import l2
from keras.callbacks import EarlyStopping
from importlib.machinery import SourceFileLoader
from keras.utils import plot_model

#LMG: Para Google la librería que controla qué ejecutar:
try:
  from google.colab import drive
  drive.mount('/content/drive')
  path = '/content/drive/My Drive/TFM/01.Utils/ESIOS_contoller.py'
  path_cell_controller = '/content/drive/My Drive/TFM/01.Utils/skip_kernel_extension.py'
  in_colab = True
except:
  path = '../utils/ESIOS_contoller.py'
  path_cell_controller = '../utils/skip_kernel_extension.py'
  in_colab = False
  
path_cell_controller = '/content/drive/My Drive/TFM/01.Utils/skip_kernel_extension.py'
cell_controller = SourceFileLoader('cell_controller', path_cell_controller).load_module()
# %load_ext cell_controller

esios_assembler = SourceFileLoader('esios', path).load_module()

esios_controller = esios_assembler.ESIOS(in_colab)
data_consumo = esios_controller.get_data()
# Out:
# Using TensorFlow backend.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Mostrando los datos de data_total.csv
# (30555, 30)
# ________________________________________________________________________________

# %%
data_consumo.head()
# Out:
#                        fecha  PVPC_DEF  ...  Precio SPOT FR  PVPC-target
# 0  2015-10-01 00:00:00+02:00    117.77  ...           38.56       123.30
# 1  2015-10-01 01:00:00+02:00    117.09  ...           31.27       121.98
# 2  2015-10-01 02:00:00+02:00    114.59  ...           30.66       126.70
# 3  2015-10-01 03:00:00+02:00    116.60  ...           29.14       131.63
# 4  2015-10-01 04:00:00+02:00    122.07  ...           29.40       134.73
#
# [5 rows x 30 columns]

# %% [markdown]
# ##Predicción hora actual con los datos actuales

# %% [markdown]
# Tomamos como variables el precio y el diferenciado.
#
# El valor diferencial ha de ser entre el día de ayer y el de antes de ayer, ya que el valor de hoy no lo tenemos a priori (sería el objetivo a calcular). Por ello, el cálculo de ésta empezará el día 3. De manera similar, el precio de ayer lo tendremos un día depués:

# %%
#------
#X_data
#------
x_data = data_consumo[['PVPC_DEF']].copy()

data_1 = data_consumo['PVPC_DEF']
data_2 = data_consumo['PVPC_DEF'].shift(periods=24, axis = 0)
x_data['PVPC_stationary_yesterday'] = (data_1 - data_2)
x_data = x_data.bfill()


x_data_columns = x_data.columns

#------
#Y_data
#------
y_data = data_consumo[['PVPC-target']].copy()
y_data_columns = y_data.columns

# %%
x_data.head()
# Out:
#    PVPC_DEF  PVPC_stationary_yesterday
# 0    117.77                       5.53
# 1    117.09                       5.53
# 2    114.59                       5.53
# 3    116.60                       5.53
# 4    122.07                       5.53

# %%
y_data.head()
# Out:
#    PVPC-target
# 0       123.30
# 1       121.98
# 2       126.70
# 3       131.63
# 4       134.73

# %% [markdown]
# Separamos los datos en train y test, y los normalizamos:

# %%
#Min-max scaler
scaler = MinMaxScaler()
x_data_norm = scaler.fit_transform(x_data)
y_data_norm = scaler.fit_transform(y_data)

# Split the data
x_train, x_valid, y_train, y_valid = train_test_split(x_data_norm, y_data_norm, test_size=0.33, shuffle=False)

#Convert NaN values to 0:
x_train = np.nan_to_num(x_train)
x_valid = np.nan_to_num(x_valid)
y_train = np.nan_to_num(y_train)
y_valid = np.nan_to_num(y_valid)

print('Xtrain_dim:', x_train.shape)
print('Ytrain_dim:', y_train.shape)
# Out:
# Xtrain_dim: (20471, 2)
# Ytrain_dim: (20471, 1)

# %% [markdown]
# Veamos cómo queda:

# %%
x_train_DF = pd.DataFrame(x_train, columns = x_data_columns)
x_train_DF.head()
# Out:
#    PVPC_DEF  PVPC_stationary_yesterday
# 0  0.468270                   0.525143
# 1  0.462688                   0.525143
# 2  0.442164                   0.525143
# 3  0.458665                   0.525143
# 4  0.503571                   0.525143

# %% [markdown]
# Por último, generamos funciones y variables de utilidad a lo largo de todos los modelos:

# %%
def rmse (y_true, y_pred):
  return K.sqrt(K.mean(K.square(y_pred -y_true), axis=-1))

# %% [markdown]
# ###NN

# %% [markdown]
# Red neuronal densa como punto de partida.

# %% [markdown]
# ####Preparación de datos

# %% [markdown]
# Primero, estandarizamos los **datos de entrenamiento**:

# %%
# %%skip $skipDenseAct
#
# scaler = MinMaxScaler()
# x_train_data = scaler.fit_transform(x_train)
# y_train_data = scaler.fit_transform(y_train)
# x_valid_data = x_valid
# y_valid_data = y_valid
#
# print('Entrenamiento:',x_train_data.shape, y_train_data.shape)
# print('Test:',x_valid_data.shape, y_valid_data.shape)

# %% [markdown]
# Para visualizar (ver apartado Visualización de dataframes al final):

# %%
# %%skip $skipDenseAct
#
# x_train_data_DF = pd.DataFrame(x_train_data, columns = x_data_columns)
# display(x_train_data_DF[0:5])

# %%
# %%skip $skipDenseAct
#
# y_train_data_DF = pd.DataFrame(y_train_data, columns = y_data_columns)
# display(y_train_data_DF[0:5])

# %% [markdown]
# Por último, definimos los tamaños de nuestra red y algunas variables adicionales

# %% [markdown]
# ####Modelo

# %%
# %%skip $skipDenseAct
#
# #Carga variables:
# split_steps = 5
# num_steps = split_steps
# output_size = y_train_data.shape[1]
# batch_size = 30

# %%
# %%skip $skipDenseAct
#
# # define model
# model = Sequential()
# model.add(Dense(100, activation='relu', input_shape=(num_var,)))
# model.add(Dense(100, activation='relu'))
# model.add(Dense(output_size, activation='linear'))
#
# # compile mode
# model.compile(optimizer='adam', loss='mse', metrics=['mse',rmse,'mae','mape'])
# print(model.summary())

# %% [markdown]
# ####Entrenamiento

# %%
# %%skip $skipDenseAct
#
# history_train = model.fit(x_train_data, y_train_data,
#                           epochs=100,
#                           batch_size=batch_size,
#                           shuffle=False,
#                           verbose=1)
#
# # summarize history for loss, MAPE in a different scale than the others
# plt.plot(history_train.history['mean_squared_error'])
# plt.plot(history_train.history['mean_absolute_error'])
# plt.plot(history_train.history['rmse'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['MSE','MAE','RMSE'], loc='upper left')
# plt.show()
#
# plt.plot(history_train.history['mean_absolute_percentage_error'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['MAPE'], loc='upper left')
# plt.show()

# %% [markdown]
# ####Test

# %% [markdown]
# Para el test:

# %%
# %%skip $skipDenseAct
#
# scores_test = model.evaluate(x_valid_data, y_valid_data, batch_size=batch_size, verbose=1)
#
# # summarize loss
# for element in range(len(scores_test)):
#   print("%s: %.2f" % (model.metrics_names[element], scores_test[element]))

# %%
# %%skip $skipDenseAct
#
# x_valid_data_DF = pd.DataFrame(x_valid_data, columns = x_data_columns)
# display(x_valid_data_DF[0:5])

# %%
# %%skip $skipDenseAct
#
# y_valid_data_DF = pd.DataFrame(y_valid_data, columns = y_data_columns)
# display(y_valid_data_DF[0:5])

# %%
# %%skip $skipDenseAct
#
# y_predict = model.predict(x_valid_data, batch_size=batch_size, verbose=1)
#
# plt.figure(figsize=(10, 10))
#
# plt.subplot(311)
# plt.plot(y_predict, c='seagreen', alpha=0.6)
# plt.title('Predict')
# plt.subplot(312)
# plt.plot(y_valid_data, c='orange', alpha=0.5)
# plt.title('Real')
# plt.subplot(313)
# plt.plot(y_predict, c='seagreen', alpha=0.6)
# plt.plot(y_valid_data, c='orange', alpha=0.5)
# plt.legend(['Predicción','Real'])
# plt.title('Predict + Real')
# plt.suptitle('Categorical Plotting')
# plt.show()

# %% [markdown]
# ###LSTM

# %% [markdown]
# Basado en el ejemplo completo que está explicado en https://adventuresinmachinelearning.com/keras-lstm-tutorial/

# %% [markdown]
# ####Preparación de datos

# %%
# %%skip $skipLSTMAct
#
# #Carga variables:
# split_steps = 5
# num_steps = split_steps
# batch_size = 30

# %% [markdown]
# Para que se ejecute en paquetes, replicamos el dataset de n en n lotes:

# %%
# %%skip $skipLSTMAct
#
# # split a sequence into samples
# def split_sequence(sequence, n_steps):
#   X = list()
#   for i in range(len(sequence)):
#     # find the end of this pattern
#     end_ix = i + n_steps
#     # check if we are beyond the sequence
#     if end_ix > len(sequence)-1:
#       break
#     # gather input and output parts of the pattern
#     seq_x = sequence[i:end_ix,:]
#     X.append(seq_x)
#
#   return np.array(X)

# %% [markdown]
# Después, estandarizamos los **datos de entrenamiento** y aplicamos la función a la x e y, agrupando las salidas por paquetes de num_steps:

# %%
# %%skip $skipLSTMAct
#
# x_train_est = x_train
# y_train_est = y_train
#
# x_train_data = split_sequence(x_train_est, split_steps)
# y_train_data = y_train_est[split_steps:,:]
# x_valid_data = split_sequence(x_valid, split_steps)
# y_valid_data = y_valid[split_steps:,:]
#
# print('Entrenamiento:',x_train_data.shape, y_train_data.shape)
# print('Test:',x_valid_data.shape, y_valid_data.shape)
# Out:
# Entrenamiento: (20466, 5, 2) (20466, 1)
# Test: (10079, 5, 2) (10079, 1)

# %% [markdown]
# Para visualizar uno de los datos que van a entrar (ver apartado Visualización de dataframes al final):

# %%
# %%skip $skipLSTMAct
#
# x_train_data_DF = pd.DataFrame(x_train_data[0,:,:], columns = x_data_columns)
# display(x_train_data_DF[0:5])
# Out:
#    PVPC_DEF  PVPC_stationary_yesterday
# 0  0.468270                   0.525143
# 1  0.462688                   0.525143
# 2  0.442164                   0.525143
# 3  0.458665                   0.525143
# 4  0.503571                   0.525143

# %%
# %%skip $skipLSTMAct
#
# y_train_data_DF = pd.DataFrame(y_train_data[0:split_steps], columns = y_data_columns)
# display(y_train_data_DF[0:5])
# Out:
#    PVPC-target
# 0     0.724170
# 1     0.724280
# 2     0.715131
# 3     0.701874
# 4     0.698641

# %% [markdown]
# Por último, definimos los tamaños de nuestra red y algunas variables adicionales:
#
# En nuestro caso, la entrada va a ser de *1* **x** *nº de datos tomados* **x** *nº de variables independientes*, siendo:
#
# - batch_size, para cada instante tomamos los datos en paquetes.
# - nº de datos tomados o num_steps, esto es, en el análisis secuencial cada registro energético completo con el que contamos, o en términos más coloquiales, cuántas filas del dataset se tienen en cuenta .
# - nº de variables independientes o num_var, cada registro en los datos de entrada, o en términos más coloquiales, cada columna del dataset.
#
# Además:
#
# - hidden_size, número de unidades en cada célula del LSTM.
#
# - A la salida, tenemos los tres valores a estimar.

# %%
# %%skip $skipLSTMAct
#
# #Carga variables:
# num_var = x_train_data.shape[2]
# output_size = y_train_data.shape[1]

# %% [markdown]
# ####Modelo

# %% [markdown]
# A la capa LSTM se le pasa cada vez un instante, siendo el primero el t1, el segundo el t2, etc.
#
# Respecto al ejemplo en la página, hemos:
# - Quitado el embedding inicial, ya que no necesitamos codificar la entrada (ya son valores en sí mismos).
# - Cambiado el hidden-layer-size. En la página dicen que se suele poner al tamaño de entrada de cada registro. Viene a ser el símil de unidades en una capa densa.
# - Dejado una única capa LSTM.
# - Eliminado el dropout.
# - TimeDistributed usa una capa densa para cada step del entrenamiento. La quitamos también y dejamos la densa exclusivamente, ya que hace la salida muy grande.
#
# Además:
#
# - No usamos regularización ni Dropout, ya que no hay problemas de overfitting.
# - Usamos normalización entre capas y a la entrada (BatchNormalization). Por ello, nos ahorramos calcular los biases, ya que no tiene sentido.
#
# Así:

# %%
# %%skip $skipLSTMAct
#
# # define model
# model = Sequential()
#
# #LSTM tiene por defecto inicialización Xavier, que para problemas lineales es la recomendada
# model.add(LSTM(100, input_shape=(num_steps,num_var)))
# model.add(Activation("relu"))
# #model.add(Dropout(0.2))
#
# model.add(Dense(output_size))
# model.add(Activation("linear"))
#
# # compile mode
# model.compile(optimizer='adam', loss='mse', metrics=['mse',rmse,'mae','mape'])
# model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               41200
# _________________________________________________________________
# activation_1 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 41,301
# Trainable params: 41,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%skip $skipLSTMAct
#
# plot_model(model,show_shapes=True)

# %% [markdown]
# ####Entrenamiento

# %%
# %%skip $skipLSTMAct
#
# print('LSTM')
# history_train = model.fit(x_train_data, y_train_data,
#                           epochs=100,
#                           batch_size=batch_size,
#                           shuffle=False,
#                           verbose=1)
#
# # summarize history for loss, MAPE in a different scale than the others
# plt.plot(history_train.history['mean_squared_error'])
# plt.plot(history_train.history['mean_absolute_error'])
# plt.plot(history_train.history['rmse'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['MSE','MAE','RMSE'], loc='upper left')
# plt.show()
#
# plt.plot(history_train.history['mean_absolute_percentage_error'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['MAPE'], loc='upper left')
# plt.show()
# Out:
# LSTM
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 20466/20466 [==============================] - 6s 306us/step - loss: 0.0121 - mean_squared_error: 0.0121 - rmse: 0.0652 - mean_absolute_error: 0.0652 - mean_absolute_percentage_error: 10.9210
# Epoch 2/100
# 20466/20466 [==============================] - 5s 243us/step - loss: 0.0042 - mean_squared_error: 0.0042 - rmse: 0.0486 - mean_absolute_error: 0.0486 - mean_absolute_percentage_error: 8.3292
# Epoch 3/100
# 20466/20466 [==============================] - 5s 240us/step - loss: 0.0041 - mean_squared_error: 0.0041 - rmse: 0.0478 - mean_absolute_error: 0.0478 - mean_absolute_percentage_error: 8.2342
# Epoch 4/100
# 20466/20466 [==============================] - 5s 242us/step - loss: 0.0041 - mean_squared_error: 0.0041 - rmse: 0.0473 - mean_absolute_error: 0.0473 - mean_absolute_percentage_error: 8.1625
# Epoch 5/100
# 20466/20466 [==============================] - 5s 243us/step - loss: 0.0041 - mean_squared_error: 0.0041 - rmse: 0.0471 - mean_absolute_error: 0.0471 - mean_absolute_percentage_error: 8.1345
# Epoch 6/100
# 20466/20466 [==============================] - 5s 243us/step - loss: 0.0040 - mean_squared_error: 0.0040 - rmse: 0.0466 - mean_absolute_error: 0.0466 - mean_absolute_percentage_error: 8.0525
# Epoch 7/100
# 20466/20466 [==============================] - 5s 241us/step - loss: 0.0039 - mean_squared_error: 0.0039 - rmse: 0.0464 - mean_absolute_error: 0.0464 - mean_absolute_percentage_error: 8.0245
# Epoch 8/100
# 20466/20466 [==============================] - 5s 243us/step - loss: 0.0039 - mean_squared_error: 0.0039 - rmse: 0.0462 - mean_absolute_error: 0.0462 - mean_absolute_percentage_error: 7.9787
# Epoch 9/100
# 20466/20466 [==============================] - 5s 240us/step - loss: 0.0039 - mean_squared_error: 0.0039 - rmse: 0.0460 - mean_absolute_error: 0.0460 - mean_absolute_percentage_error: 7.9558
# Epoch 10/100
# 20466/20466 [==============================] - 5s 240us/step - loss: 0.0039 - mean_squared_error: 0.0039 - rmse: 0.0459 - mean_absolute_error: 0.0459 - mean_absolute_percentage_error: 7.9286
# Epoch 11/100
# 20466/20466 [==============================] - 5s 242us/step - loss: 0.0038 - mean_squared_error: 0.0038 - rmse: 0.0456 - mean_absolute_error: 0.0456 - mean_absolute_percentage_error: 7.8858
# Epoch 12/100
# 20466/20466 [==============================] - 5s 239us/step - loss: 0.0038 - mean_squared_error: 0.0038 - rmse: 0.0455 - mean_absolute_error: 0.0455 - mean_absolute_percentage_error: 7.8769
# Epoch 13/100
# Epoch 88/100
# 20466/20466 [==============================] - 5s 232us/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0437 - mean_absolute_error: 0.0437 - mean_absolute_percentage_error: 7.5491
# Epoch 89/100
# 20466/20466 [==============================] - 5s 231us/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0437 - mean_absolute_error: 0.0437 - mean_absolute_percentage_error: 7.5530
# Epoch 90/100
# 20466/20466 [==============================] - 5s 232us/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0436 - mean_absolute_error: 0.0436 - mean_absolute_percentage_error: 7.5431
# Epoch 91/100
# 20466/20466 [==============================] - 5s 236us/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0437 - mean_absolute_error: 0.0437 - mean_absolute_percentage_error: 7.5454
# Epoch 92/100
# 20466/20466 [==============================] - 5s 237us/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0436 - mean_absolute_error: 0.0436 - mean_absolute_percentage_error: 7.5417
# Epoch 93/100
# 20466/20466 [==============================] - 5s 236us/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0436 - mean_absolute_error: 0.0436 - mean_absolute_percentage_error: 7.5361
# Epoch 94/100
# 20466/20466 [==============================] - 5s 236us/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0436 - mean_absolute_error: 0.0436 - mean_absolute_percentage_error: 7.5329
# Epoch 95/100
# 20466/20466 [==============================] - 5s 233us/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0435 - mean_absolute_error: 0.0435 - mean_absolute_percentage_error: 7.5248
# Epoch 96/100
# 20466/20466 [==============================] - 5s 239us/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0435 - mean_absolute_error: 0.0435 - mean_absolute_percentage_error: 7.5191
# Epoch 97/100
# 20466/20466 [==============================] - 5s 238us/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0435 - mean_absolute_error: 0.0435 - mean_absolute_percentage_error: 7.5168
# Epoch 98/100
# 20466/20466 [==============================] - 5s 236us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0435 - mean_absolute_error: 0.0435 - mean_absolute_percentage_error: 7.5114
# Epoch 99/100
# 20466/20466 [==============================] - 5s 233us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0434 - mean_absolute_error: 0.0434 - mean_absolute_percentage_error: 7.5028
# Epoch 100/100
# 20466/20466 [==============================] - 5s 236us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0434 - mean_absolute_error: 0.0434 - mean_absolute_percentage_error: 7.5004

# %% [markdown]
# ####Test

# %% [markdown]
# Para el test:

# %%
# %%skip $skipLSTMAct
#
# scores_test = model.evaluate(x_valid_data, y_valid_data, batch_size=batch_size, verbose=1)
#
# # summarize loss
# for element in range(len(scores_test)):
#   print("%s: %.2f" % (model.metrics_names[element], scores_test[element]))
# Out:
# 10079/10079 [==============================] - 1s 54us/step
# loss: 0.01
# mean_squared_error: 0.01
# rmse: 0.06
# mean_absolute_error: 0.06
# mean_absolute_percentage_error: 1407730.39

# %%
# %%skip $skipLSTMAct
#
# x_valid_data_DF = pd.DataFrame(x_valid_data[0,:,:], columns = x_data_columns)
# display(x_valid_data_DF)
# Out:
#    PVPC_DEF  PVPC_stationary_yesterday
# 0  0.482637                   0.548007
# 1  0.483129                   0.551769
# 2  0.482883                   0.545330
# 3  0.502996                   0.563997
# 4  0.522946                   0.551769

# %%
# %%skip $skipLSTMAct
#
# y_valid_data_DF = pd.DataFrame(y_valid_data[0:5,:], columns = y_data_columns)
# display(y_valid_data_DF)
# Out:
#    PVPC-target
# 0     0.680673
# 1     0.678974
# 2     0.662540
# 3     0.679194
# 4     0.679194

# %%
# %%skip $skipLSTMAct
#
# y_predict = model.predict(x_valid_data, batch_size=batch_size, verbose=1)
#
# plt.figure(figsize=(10, 10))
#
# plt.subplot(311)
# plt.plot(y_predict, c='seagreen', alpha=0.6)
# plt.title('Predict')
# plt.subplot(312)
# plt.plot(y_valid_data, c='orange', alpha=0.5)
# plt.title('Real')
# plt.subplot(313)
# plt.plot(y_predict, c='seagreen', alpha=0.6)
# plt.plot(y_valid_data, c='orange', alpha=0.5)
# plt.legend(['Predicción','Real'])
# plt.title('Predict + Real')
# plt.suptitle('Categorical Plotting')
# plt.show()
# Out:
# 10079/10079 [==============================] - 1s 51us/step

# %% [markdown]
# ##Predicción a 24 h con los datos actuales (segregado por horas)
#
# Sería la predicción de mañana una vez tenemos los datos de la hora actual, incluido el precio.
#
# En los ejercicios anteriores hemos calculado la predicción a la hora siguiente. En este ejercicio vamos a intentar calcular la predicción con la hora del día siguiente, para ello utilizaremos el PVPC_DEF como precio de la hora actual, el PVCP-target como el precio de la hora del día siguiente, y calcularemos la diferencia moviendose una ventana de 24 horas.

# %% [markdown]
# ###LSTM

# %% [markdown]
# ####Preparación de datos

# %%
# %%skip $skipLSTM24Seg
#
# #Carga variables:
# split_steps = 5
# num_steps = split_steps
# batch_size = 30

# %%
# %%skip $skipLSTM24Seg
#
# #------
# #X_data
# #------
# x_data = data_consumo[['PVPC_DEF']].copy()
#
# data_1 = data_consumo['PVPC_DEF']
# data_2 = data_consumo['PVPC_DEF'].shift(periods=24, axis = 0)
# x_data['PVPC_stationary_yesterday'] = (data_1 - data_2)
# x_data = x_data.bfill()
#
#
# x_data_columns = x_data.columns
#
# #------
# #Y_data
# #------
# y_data = data_consumo[['PVPC-target']].copy()
# y_data_columns = y_data.columns

# %%
# %%skip $skipLSTM24Seg
#
# x_data[0:2]

# %%
# %%skip $skipLSTM24Seg
#
# x_data[24:26]

# %%
# %%skip $skipLSTM24Seg
#
# y_data.head()

# %%
# %%skip $skipLSTM24Seg
#
# #Min-max scaler
# scaler = MinMaxScaler()
# x_data_norm = scaler.fit_transform(x_data)
# y_data_norm = scaler.fit_transform(y_data)
#
# # Split the data
# x_train, x_valid, y_train, y_valid = train_test_split(x_data_norm, y_data_norm, test_size=0.33, shuffle=False)
#
# #Convert NaN values to 0:
# x_train = np.nan_to_num(x_train)
# x_valid = np.nan_to_num(x_valid)
# y_train = np.nan_to_num(y_train)
# y_valid = np.nan_to_num(y_valid)
#
# print('Xtrain_dim:', x_train.shape)
# print('Ytrain_dim:', y_train.shape)
# Out:
# Xtrain_dim: (20471, 2)
# Ytrain_dim: (20471, 1)

# %%
# %%skip $skipLSTM24Seg
#
# x_train_est = x_train
# y_train_est = y_train
#
# x_train_data = split_sequence(x_train_est, split_steps)
# y_train_data = y_train_est[split_steps:,:]
# x_valid_data = split_sequence(x_valid, split_steps)
# y_valid_data = y_valid[split_steps:,:]
#
# print('Entrenamiento:',x_train_data.shape, y_train_data.shape)
# print('Test:',x_valid_data.shape, y_valid_data.shape)
# Out:
# Entrenamiento: (20466, 5, 2) (20466, 1)
# Test: (10079, 5, 2) (10079, 1)

# %%
# %%skip $skipLSTM24Seg
#
# #Carga variables:
# num_var = x_train_data.shape[2]
# output_size = y_train_data.shape[1]

# %% [markdown]
# #### Modelo
# Mismo modelo que los entrenados anteriormente

# %%
# %%skip $skipLSTM24Seg
#
# # define model
# model = Sequential()
#
# #LSTM tiene por defecto inicialización Xavier, que para problemas lineales es la recomendada
# model.add(LSTM(100, input_shape=(num_steps,num_var)))
# model.add(Activation("relu"))
#
# model.add(Dense(output_size))
# model.add(Activation("linear"))
#
# # compile mode
# model.compile(optimizer='adam', loss='mse', metrics=['mse',rmse,'mae','mape'])
# model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 100)               41200
# _________________________________________________________________
# activation_3 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# _________________________________________________________________
# activation_4 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 41,301
# Trainable params: 41,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%skip $skipLSTM24Seg
#
# print('LSTM')
# history_train = model.fit(x_train_data, y_train_data,
#                           epochs=100,
#                           batch_size=batch_size,
#                           shuffle=False,
#                           verbose=1)
#
# # summarize history for loss, MAPE in a different scale than the others
# plt.plot(history_train.history['mean_squared_error'])
# plt.plot(history_train.history['mean_absolute_error'])
# plt.plot(history_train.history['rmse'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['MSE','MAE','RMSE'], loc='upper left')
# plt.show()
#
# plt.plot(history_train.history['mean_absolute_percentage_error'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['MAPE'], loc='upper left')
# plt.show()
# Out:
# LSTM
# Epoch 1/100
# 20466/20466 [==============================] - 6s 276us/step - loss: 0.0111 - mean_squared_error: 0.0111 - rmse: 0.0641 - mean_absolute_error: 0.0641 - mean_absolute_percentage_error: 10.7485
# Epoch 2/100
# 20466/20466 [==============================] - 5s 238us/step - loss: 0.0042 - mean_squared_error: 0.0042 - rmse: 0.0485 - mean_absolute_error: 0.0485 - mean_absolute_percentage_error: 8.3201
# Epoch 3/100
# 20466/20466 [==============================] - 5s 236us/step - loss: 0.0041 - mean_squared_error: 0.0041 - rmse: 0.0479 - mean_absolute_error: 0.0479 - mean_absolute_percentage_error: 8.2452
# 20466/20466 [==============================] - 5s 240us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0432 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 7.4697
# Epoch 94/100
# 20466/20466 [==============================] - 5s 238us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0432 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 7.4650
# Epoch 95/100
# 20466/20466 [==============================] - 5s 237us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0432 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 7.4622
# Epoch 96/100
# 20466/20466 [==============================] - 5s 240us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0432 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 7.4613
# Epoch 97/100
# 20466/20466 [==============================] - 5s 243us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0432 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 7.4599
# Epoch 98/100
# 20466/20466 [==============================] - 5s 239us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0432 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 7.4593
# Epoch 99/100
# 20466/20466 [==============================] - 5s 237us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0432 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 7.4576
# Epoch 100/100
# 20466/20466 [==============================] - 5s 239us/step - loss: 0.0034 - mean_squared_error: 0.0034 - rmse: 0.0432 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 7.4595

# %% [markdown]
# #### Plot

# %%
# %%skip $skipLSTM24Seg
#
# y_predict = model.predict(x_valid_data, batch_size=batch_size, verbose=1)
#
# plt.figure(figsize=(10, 10))
#
# plt.subplot(311)
# plt.plot(y_predict, c='seagreen', alpha=0.6)
# plt.title('Predict')
# plt.subplot(312)
# plt.plot(y_valid_data, c='orange', alpha=0.5)
# plt.title('Real')
# plt.subplot(313)
# plt.plot(y_predict, c='seagreen', alpha=0.6)
# plt.plot(y_valid_data, c='orange', alpha=0.5)
# plt.legend(['Predicción','Real'])
# plt.title('Predict + Real')
# plt.suptitle('Categorical Plotting')
# plt.show()
# Out:
# 10079/10079 [==============================] - 1s 59us/step

# %% [markdown]
# #### Metrics

# %%
# %%skip $skipLSTM24Seg
#
# esios_controller.get_metrics(y_valid_data, y_predict)
# Out:
# ** --------------- Metrics: --------------- **
# MSE:  0.005397443823516547
# RMSE:  0.07346729764675264
# MAE:  0.05827285406503227
# Log_MSE:  0.0021590513600753315
# MedianAE:  0.05390472364174892
# MAPE:  inf %
# SMAPE:  9.119202853206113 %
# Variance:  0.32209286441376495
# Max Error:  0.6098700761795044
# ** ---------------------------------------- **
# /content/drive/My Drive/TFM/01.Utils/ESIOS_contoller.py:125: RuntimeWarning: divide by zero encountered in true_divide
#   mape = np.mean(abs((y_real-y_pred)/y_real))*100

# %% [markdown]
# #### Plot real
#
# Vamos a aplicarle el scaler inverse para ver las predicciones reales

# %%
# %%skip $skipLSTM24Seg
#
# y_predict_trans = scaler.inverse_transform(y_predict)
# y_valid_trans = scaler.inverse_transform(y_valid_data)

# %%
# %%skip $skipLSTM24Seg
#
# plt.figure(figsize=(10, 10))
#
# plt.subplot(311)
# plt.plot(y_predict_trans, c='seagreen', alpha=0.6)
# plt.title('Predict')
# plt.subplot(312)
# plt.plot(y_valid_trans, c='orange', alpha=0.5)
# plt.title('y_valid_trans')
# plt.subplot(313)
# plt.plot(y_predict_trans, c='seagreen', alpha=0.6)
# plt.plot(y_valid_trans, c='orange', alpha=0.5)
# plt.legend(['Predicción','Real'])
# plt.title('Predict + Real')
# plt.suptitle('Categorical Plotting')
# plt.show()

# %% [markdown]
# #### Metrics real

# %%
# %%skip $skipLSTM24Seg
#
# esios_controller.get_metrics(y_valid_trans, y_predict_trans)
# Out:
# ** --------------- Metrics: --------------- **
# MSE:  179.84742499035247
# RMSE:  13.41072052465312
# MAE:  10.637126783765913
# Log_MSE:  0.06266044670560658
# MedianAE:  9.839766845703124
# MAPE:  inf %
# SMAPE:  9.119202854542545 %
# Variance:  0.32209286078408117
# Max Error:  111.32568359375
# ** ---------------------------------------- **
# /content/drive/My Drive/TFM/01.Utils/ESIOS_contoller.py:125: RuntimeWarning: divide by zero encountered in true_divide
#   mape = np.mean(abs((y_real-y_pred)/y_real))*100

# %% [markdown]
# ## Predicción a 24 h con los datos actuales (agrupado por día)

# %% [markdown]
# ###LSTM

# %% [markdown]
# #### Preparación de datos
# En este caso nos vamos a traer los datos agrupados diariamente, aplicaremos el mismo proceso que hemos aplicado antes, y esta vez la diferencia entre el día de hoy y el anterior será de 1 período.

# %%
# %%skip $skipLSTM24Agr
#
# #Carga variables:
# split_steps = 5
# num_steps = split_steps
# batch_size = 30

# %%
# %%skip $skipLSTM24Agr
#
# x_data_grouped = esios_controller.get_df_daily()
# x_data = list()
# y_data = list()
#
# x_data = x_data_grouped[['PVPC_DEF']].copy()
#
# data_1 = x_data_grouped['PVPC_DEF']
# data_2 = x_data_grouped['PVPC_DEF'].shift(periods=1, axis = 0)
# x_data['PVPC_stationary_yesterday'] = (data_1 - data_2)
# x_data = x_data.bfill()
#
#
# x_data_columns = x_data.columns
#
#
# #------
# #Y_data
# #------
# y_data = pd.DataFrame(x_data_grouped['PVPC_DEF'].shift(periods=-1, axis = 0).copy())

# %%
# %%skip $skipLSTM24Agr
#
# display(x_data[0:5])
# Out:
#                              PVPC_DEF  PVPC_stationary_yesterday
# fecha
# 2015-09-30 00:00:00+00:00  117.430000                   7.168571
# 2015-10-01 00:00:00+00:00  124.598571                   7.168571
# 2015-10-02 00:00:00+00:00  122.746957                  -1.851615
# 2015-10-03 00:00:00+00:00  114.161667                  -8.585290
# 2015-10-04 00:00:00+00:00  101.120833                 -13.040833

# %%
# %%skip $skipLSTM24Agr
#
# display(y_data[0:5])
# Out:
#                              PVPC_DEF
# fecha
# 2015-09-30 00:00:00+00:00  124.598571
# 2015-10-01 00:00:00+00:00  122.746957
# 2015-10-02 00:00:00+00:00  114.161667
# 2015-10-03 00:00:00+00:00  101.120833
# 2015-10-04 00:00:00+00:00  106.640000

# %%
# %%skip $skipLSTM24Agr
#
# #Min-max scaler
# scaler = MinMaxScaler()
# x_data_norm = scaler.fit_transform(x_data)
# y_data_norm = scaler.fit_transform(y_data)
#
# # Split the data
# x_train, x_valid, y_train, y_valid = train_test_split(x_data_norm, y_data_norm, test_size=0.33, shuffle=False)
#
# #Convert NaN values to 0:
# x_train = np.nan_to_num(x_train)
# x_valid = np.nan_to_num(x_valid)
# y_train = np.nan_to_num(y_train)
# y_valid = np.nan_to_num(y_valid)
#
# print('Xtrain_dim:', x_train.shape)
# print('Ytrain_dim:', y_train.shape)
# Out:
# Xtrain_dim: (938, 2)
# Ytrain_dim: (938, 1)

# %%
# %%skip $skipLSTM24Agr
#
# x_train_est = x_train
# y_train_est = y_train
#
# x_train_data = split_sequence(x_train_est, split_steps)
# y_train_data = y_train_est[split_steps:,:]
# x_valid_data = split_sequence(x_valid, split_steps)
# y_valid_data = y_valid[split_steps:,:]
#
# print('Entrenamiento:',x_train_data.shape, y_train_data.shape)
# print('Test:',x_valid_data.shape, y_valid_data.shape)
# Out:
# Entrenamiento: (933, 5, 2) (933, 1)
# Test: (458, 5, 2) (458, 1)

# %%
# %%skip $skipLSTM24Agr
#
# #Carga variables:
# num_var = x_train_data.shape[2]
# output_size = y_train_data.shape[1]

# %% [markdown]
# #### Modelo
# Mismo modelo que los entrenados anteriormente

# %%
# %%skip $skipLSTM24Agr
#
# # define model
# model = Sequential()
#
# #LSTM tiene por defecto inicialización Xavier, que para problemas lineales es la recomendada
# model.add(LSTM(100, input_shape=(num_steps,num_var)))
# model.add(Activation("relu"))
#
# model.add(Dense(output_size))
# model.add(Activation("linear"))
#
# # compile mode
# model.compile(optimizer='adam', loss='mse', metrics=['mse',rmse,'mae','mape'])
# model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 100)               41200
# _________________________________________________________________
# activation_3 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# _________________________________________________________________
# activation_4 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 41,301
# Trainable params: 41,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%skip $skipLSTM24Agr
#
# print('LSTM')
# history_train = model.fit(x_train_data, y_train_data,
#                           epochs=300,
#                           batch_size=batch_size,
#                           shuffle=False,
#                           verbose=1)
#
# # summarize history for loss, MAPE in a different scale than the others
# plt.plot(history_train.history['mean_squared_error'])
# plt.plot(history_train.history['mean_absolute_error'])
# plt.plot(history_train.history['rmse'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['MSE','MAE','RMSE'], loc='upper left')
# plt.show()
#
# plt.plot(history_train.history['mean_absolute_percentage_error'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['MAPE'], loc='upper left')
# plt.show()
# Out:
# LSTM
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1
# Epoch 288/300
# 933/933 [==============================] - 0s 282us/step - loss: 0.0059 - mean_squared_error: 0.0059 - rmse: 0.0552 - mean_absolute_error: 0.0552 - mean_absolute_percentage_error: 243156.5535
# Epoch 289/300
# 933/933 [==============================] - 0s 321us/step - loss: 0.0056 - mean_squared_error: 0.0056 - rmse: 0.0537 - mean_absolute_error: 0.0537 - mean_absolute_percentage_error: 226150.7768
# Epoch 290/300
# 933/933 [==============================] - 0s 293us/step - loss: 0.0060 - mean_squared_error: 0.0060 - rmse: 0.0556 - mean_absolute_error: 0.0556 - mean_absolute_percentage_error: 241471.1754
# Epoch 291/300
# 933/933 [==============================] - 0s 289us/step - loss: 0.0057 - mean_squared_error: 0.0057 - rmse: 0.0540 - mean_absolute_error: 0.0540 - mean_absolute_percentage_error: 230781.3293
# Epoch 292/300
# 933/933 [==============================] - 0s 286us/step - loss: 0.0059 - mean_squared_error: 0.0059 - rmse: 0.0554 - mean_absolute_error: 0.0554 - mean_absolute_percentage_error: 228119.1468
# Epoch 293/300
# 933/933 [==============================] - 0s 274us/step - loss: 0.0057 - mean_squared_error: 0.0057 - rmse: 0.0542 - mean_absolute_error: 0.0542 - mean_absolute_percentage_error: 236424.5283
# Epoch 294/300
# 933/933 [==============================] - 0s 293us/step - loss: 0.0058 - mean_squared_error: 0.0058 - rmse: 0.0550 - mean_absolute_error: 0.0550 - mean_absolute_percentage_error: 251407.4491
# Epoch 295/300
# 933/933 [==============================] - 0s 259us/step - loss: 0.0057 - mean_squared_error: 0.0057 - rmse: 0.0537 - mean_absolute_error: 0.0537 - mean_absolute_percentage_error: 220115.1042
# Epoch 296/300
# 933/933 [==============================] - 0s 258us/step - loss: 0.0059 - mean_squared_error: 0.0059 - rmse: 0.0553 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 249959.2647
# Epoch 297/300
# 933/933 [==============================] - 0s 262us/step - loss: 0.0056 - mean_squared_error: 0.0056 - rmse: 0.0537 - mean_absolute_error: 0.0537 - mean_absolute_percentage_error: 211227.8595
# Epoch 298/300
# 933/933 [==============================] - 0s 277us/step - loss: 0.0059 - mean_squared_error: 0.0059 - rmse: 0.0553 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 255903.2812
# Epoch 299/300
# 933/933 [==============================] - 0s 302us/step - loss: 0.0056 - mean_squared_error: 0.0056 - rmse: 0.0532 - mean_absolute_error: 0.0532 - mean_absolute_percentage_error: 206616.8299
# Epoch 300/300
# 933/933 [==============================] - 0s 284us/step - loss: 0.0059 - mean_squared_error: 0.0059 - rmse: 0.0555 - mean_absolute_error: 0.0555 - mean_absolute_percentage_error: 248768.1457

# %%
# %%skip $skipLSTM24Agr
#
# y_predict = model.predict(x_valid_data, batch_size=batch_size, verbose=1)
#
# plt.figure(figsize=(10, 10))
#
# plt.subplot(311)
# plt.plot(y_predict, c='seagreen', alpha=0.6)
# plt.title('Predict')
# plt.subplot(312)
# plt.plot(y_valid_data, c='orange', alpha=0.5)
# plt.title('Real')
# plt.subplot(313)
# plt.plot(y_predict, c='seagreen', alpha=0.6)
# plt.plot(y_valid_data, c='orange', alpha=0.5)
# plt.legend(['Predicción','Real'])
# plt.title('Predict + Real')
# plt.suptitle('Categorical Plotting')
# plt.show()
# Out:
# 458/458 [==============================] - 0s 342us/step

# %% [markdown]
# #### Encoder
#
# Nos traemos el encoder y hacemos la predicción

# %%
# %%skip $skipLSTM24Agr
#
# y_predict_trans = scaler.inverse_transform(y_predict)
# y_valid_trans = scaler.inverse_transform(y_valid_data)
#
# predictions = pd.DataFrame(y_predict_trans)
# print(np.shape(predictions))
# print(np.shape(y_valid_trans))
# Out:
# (458, 1)
# (458, 1)

# %%
# %%skip $skipLSTM24Agr
#
# predictions['Holiday'] = x_data_grouped[-458:]['Holiday'].values
# np.shape(predictions)

# %% [markdown]
# importar el encoder

# %%
# %%skip $skipLSTM24Agr
#
# encoder = esios_controller.load_keras_model('/content/drive/My Drive/TFM/01.Utils/data/Encoder.json')
# Out:
# /content/drive/My Drive/TFM/01.Utils/data/Encoder.json
# Loaded model from disk

# %%
# %%skip $skipLSTM24Agr
#
# all_day_real_preds = encoder.predict(predictions);
# print(np.shape(all_day_real_preds))
# Out:
# (458, 24)

# %% [markdown]
# #### Predic data parse
#
# Como en todos los días no tenemos el total de las 24 horas debemos eliminar algunas de estas en el predict, que este sí que genera las 24.

# %%
# %%skip $skipLSTM24Agr
#
# y_data_target = esios_controller.get_df_daily_target_day_prics()
# y_data_target = pd.DataFrame(y_data_target.values.tolist(), columns=['h'+str(i) for i in range(24)])
#
# y_data_target_for_test = y_data_target[-458:]
# np.shape(y_data_target_for_test)

# %%
# %%skip $skipLSTM24Agr
#
# import math
# pred = list()
# real = list()
#
# day_key = 0
# for day in y_data_target_for_test.values:
#   hour_key = 0
#   for hour in day:
#     if not math.isnan(hour) and hour != 0:
#       real.append(hour)
#       pred.append(all_day_real_preds[day_key][hour_key])
#     hour_key += 1
#   day_key += 1
#
#
# print(np.shape(pred))
# print(np.shape(real))
# Out:
# (10237,)
# (10237,)

# %% [markdown]
# #### Plot

# %%
# %%skip $skipLSTM24Agr
#
# plt.figure(figsize=(10, 10))
#
# plt.subplot(311)
# plt.plot(pred, c='seagreen', alpha=0.6)
# plt.title('Predict')
# plt.subplot(312)
# plt.plot(real, c='orange', alpha=0.5)
# plt.title('y_valid_trans')
# plt.subplot(313)
# plt.plot(pred, c='seagreen', alpha=0.6)
# plt.plot(real, c='orange', alpha=0.5)
# plt.legend(['Predicción','Real'])
# plt.title('Predict + Real')
# plt.suptitle('Categorical Plotting')
# plt.show()

# %% [markdown]
# #### Metrics

# %%
# %%skip $skipLSTM24Agr
#
# esios_controller.get_metrics(pd.DataFrame(real), pd.DataFrame(pred))
# Out:
# ** --------------- Metrics: --------------- **
# MSE:  63.90800170747659
# RMSE:  7.994248038901257
# MAE:  5.9410139346833075
# Log_MSE:  0.004693961437863041
# MedianAE:  4.498581542968736
# MAPE:  0    5.055953
# dtype: float64 %
# SMAPE:  0    4.967154
# dtype: float64 %
# Variance:  0.49913775901489
# Max Error:  51.88490753173828
# ** ---------------------------------------- **
